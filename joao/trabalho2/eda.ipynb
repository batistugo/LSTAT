# %%
from get_df import get_data

# %%
df = get_data()
# Out:
# /home/joaoholz/Documents/lestat/2trabalho/get_df.py:24: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df['weekofyear'] = df.date_time.dt.weekofyear

# %%
from plot import lines_plot, columnX
stations2 = list(map(lambda x: columnX(x),['A612','A613','A614','A634']))
_ = lines_plot(df,stations2,freq='W')

# %%
df.corr()
# Out:
#                                                     A613 - precipitacao total, horario (mm)  ...  hour_9**3
# A613 - precipitacao total, horario (mm)                                            1.000000  ...   0.009759
# A613 - pressao atmosferica ao nivel da estacao,...                                -0.032484  ...  -0.078699
# A613 - pressao atmosferica max. na hora ant. (a...                                -0.032556  ...  -0.077496
# A613 - pressao atmosferica min. na hora ant. (a...                                -0.037934  ...  -0.065889
# A613 - temperatura do ar - bulbo seco, horaria ...                                -0.021941  ...  -0.346198
# ...                                                                                     ...  ...        ...
# day_of_year                                                                       -0.015184  ...   0.000263
# weekofyear                                                                        -0.015454  ...   0.000264
# hour_9                                                                             0.015408  ...   0.912607
# hour_9**2                                                                          0.012791  ...   0.985819
# hour_9**3                                                                          0.009759  ...   1.000000
#
# [72 rows x 72 columns]
